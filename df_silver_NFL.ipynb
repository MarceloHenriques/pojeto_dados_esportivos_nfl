# %%
import pandas as pd
import ast

# %%
# Carregar os dados do CSV
df_silver = pd.read_csv('data_silver.csv')

# Exibir as primeiras linhas do DataFrame para verificar a estrutura
df_silver.head()
# Out:
#                                               league  \
# 0  {'id': 1, 'name': 'NFL', 'season': 2024, 'logo...
# 1  {'id': 1, 'name': 'NFL', 'season': 2024, 'logo...
# 2  {'id': 1, 'name': 'NFL', 'season': 2024, 'logo...
# 3  {'id': 1, 'name': 'NFL', 'season': 2024, 'logo...
# 4  {'id': 1, 'name': 'NFL', 'season': 2024, 'logo...
#
#                      conference   division  position  \
# 0  American Football Conference   AFC East         1
# 1  American Football Conference   AFC East         2
# 2  American Football Conference   AFC East         3
# 3  American Football Conference   AFC East         4
# 4  American Football Conference  AFC North         1
#
#                                                 team  won  lost  ties  \
# 0  {'id': 20, 'name': 'Buffalo Bills', 'logo': 'h...   13     4     0
# 1  {'id': 25, 'name': 'Miami Dolphins', 'logo': '...    8     9     0
# 2  {'id': 13, 'name': 'New York Jets', 'logo': 'h...    5    12     0
# ...

# %%
df_silver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   league           32 non-null     object
#  1   conference       32 non-null     object
#  2   division         32 non-null     object
#  3   position         32 non-null     int64
#  4   team             32 non-null     object
#  5   won              32 non-null     int64
#  6   lost             32 non-null     int64
#  7   ties             32 non-null     int64
#  8   points           32 non-null     object
#  9   records          32 non-null     object
#  10  streak           32 non-null     object
#  11  ncaa_conference  32 non-null     object
# dtypes: int64(4), object(8)
# memory usage: 3.1+ KB

# %%
df_silver['team'] = df_silver['team'].apply(lambda x: ast.literal_eval(x)['name'] if isinstance(x, str) else x)
df_silver['league'] = df_silver['league'].apply(lambda x: ast.literal_eval(x)['name'] if isinstance(x, str) else x)

# %%
df_silver.head()
# Out:
#   league                    conference   division  position  \
# 0    NFL  American Football Conference   AFC East         1
# 1    NFL  American Football Conference   AFC East         2
# 2    NFL  American Football Conference   AFC East         3
# 3    NFL  American Football Conference   AFC East         4
# 4    NFL  American Football Conference  AFC North         1
#
#                    team  won  lost  ties  \
# 0         Buffalo Bills   13     4     0
# 1        Miami Dolphins    8     9     0
# 2         New York Jets    5    12     0
# 3  New England Patriots    4    13     0
# 4      Baltimore Ravens   12     5     0
#
#                                              points  \
# 0   {'for': 525, 'against': 368, 'difference': 157}
# 1   {'for': 345, 'against': 364, 'difference': -19}
# 2   {'for': 338, 'against': 404, 'difference': -66}
# 3  {'for': 289, 'against': 417, 'difference': -128}
# 4   {'for': 518, 'against': 361, 'difference': 157}
#
# ...

# %%
df_silver = df_silver.drop(['conference', 'records', 'streak', 'ncaa_conference'],axis=1)
df_silver
# Out:
#    league   division  position                   team  won  lost  ties  \
# 0     NFL   AFC East         1          Buffalo Bills   13     4     0
# 1     NFL   AFC East         2         Miami Dolphins    8     9     0
# 2     NFL   AFC East         3          New York Jets    5    12     0
# 3     NFL   AFC East         4   New England Patriots    4    13     0
# 4     NFL  AFC North         1       Baltimore Ravens   12     5     0
# 5     NFL  AFC North         2    Pittsburgh Steelers   10     7     0
# 6     NFL  AFC North         3     Cincinnati Bengals    9     8     0
# 7     NFL  AFC North         4       Cleveland Browns    3    14     0
# 8     NFL  AFC South         1         Houston Texans   10     7     0
# 9     NFL  AFC South         2     Indianapolis Colts    8     9     0
# 10    NFL  AFC South         3   Jacksonville Jaguars    4    13     0
# 11    NFL  AFC South         4       Tennessee Titans    3    14     0
# ...

# %%
df_wins = df_silver.sort_values(by='won', ascending=False)

df_wins
# Out:
#    league   division  position                   team  won  lost  ties points
# 12    NFL   AFC West         1     Kansas City Chiefs   15     2     0     {}
# 20    NFL  NFC North         1          Detroit Lions   15     2     0     {}
# 16    NFL   NFC East         1    Philadelphia Eagles   14     3     0     {}
# 21    NFL  NFC North         2      Minnesota Vikings   14     3     0     {}
# 0     NFL   AFC East         1          Buffalo Bills   13     4     0     {}
# 17    NFL   NFC East         2  Washington Commanders   12     5     0     {}
# 4     NFL  AFC North         1       Baltimore Ravens   12     5     0     {}
# 13    NFL   AFC West         2   Los Angeles Chargers   11     6     0     {}
# 22    NFL  NFC North         3      Green Bay Packers   11     6     0     {}
# 24    NFL  NFC South         1   Tampa Bay Buccaneers   10     7     0     {}
# 29    NFL   NFC West         2       Seattle Seahawks   10     7     0     {}
# ...
